# %%
# Libraries

# %%
import numpy as np
import pandas as pd

# %%
# importing Files

# %%
content = pd.read_csv("Content.csv")
content
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# ...

# %%
reactions = pd.read_csv("Reactions.csv")
reactions
# Out:
#        Unnamed: 0                            Content ID  \
# 0               0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550       25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 0                                       NaN         NaN  2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# ...

# %%
reaction_type = pd.read_csv("ReactionTypes.csv")
reaction_type
# Out:
#     Unnamed: 0         Type Sentiment  Score
# 0            0        heart  positive     60
# 1            1         want  positive     70
# 2            2      disgust  negative      0
# 3            3         hate  negative      5
# 4            4   interested  positive     30
# 5            5  indifferent   neutral     20
# 6            6         love  positive     65
# 7            7   super love  positive     75
# 8            8      cherish  positive     70
# 9            9        adore  positive     72
# 10          10         like  positive     50
# 11          11      dislike  negative     10
# 12          12    intrigued  positive     45
# 13          13      peeking   neutral     35
# 14          14       scared  negative     15
# 15          15      worried  negative     12

# %%
# Basic Analysis

# %%
# Info

# %%
content.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   int64
#  1   Content ID  1000 non-null   object
#  2   User ID     1000 non-null   object
#  3   Type        1000 non-null   object
#  4   Category    1000 non-null   object
#  5   URL         801 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB

# %%
reactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25553 entries, 0 to 25552
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  25553 non-null  int64
#  1   Content ID  25553 non-null  object
#  2   User ID     22534 non-null  object
#  3   Type        24573 non-null  object
#  4   Datetime    25553 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 998.3+ KB

# %%
reaction_type.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  16 non-null     int64
#  1   Type        16 non-null     object
#  2   Sentiment   16 non-null     object
#  3   Score       16 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 640.0+ bytes

# %%
# Describe

# %%
content.describe()
# Out:
#         Unnamed: 0
# count  1000.000000
# mean    499.500000
# std     288.819436
# min       0.000000
# 25%     249.750000
# 50%     499.500000
# 75%     749.250000
# max     999.000000

# %%
reactions.describe()
# Out:
#         Unnamed: 0
# count  25553.00000
# mean   12776.00000
# std     7376.66005
# min        0.00000
# 25%     6388.00000
# 50%    12776.00000
# 75%    19164.00000
# max    25552.00000

# %%
reaction_type.describe()
# Out:
#        Unnamed: 0      Score
# count   16.000000  16.000000
# mean     7.500000  39.625000
# std      4.760952  26.901983
# min      0.000000   0.000000
# 25%      3.750000  14.250000
# 50%      7.500000  40.000000
# 75%     11.250000  66.250000
# max     15.000000  75.000000

# %%
# Null Values

# %%
content.isnull().sum()
# Out:
# Unnamed: 0      0
# Content ID      0
# User ID         0
# Type            0
# Category        0
# URL           199
# dtype: int64

# %%
reactions.isnull().sum()
# Out:
# Unnamed: 0       0
# Content ID       0
# User ID       3019
# Type           980
# Datetime         0
# dtype: int64

# %%
reaction_type.isnull().sum()
# Out:
# Unnamed: 0    0
# Type          0
# Sentiment     0
# Score         0
# dtype: int64

# %%
# Dropping Null Values

# %%
# Drop rows with null values in the 'URL' column
content = content.dropna(subset=['URL'])

# %%
# Drop rows with null values in the 'URL' column
reactions = reactions.dropna(subset=['User ID'])
reactions = reactions.dropna(subset=['Type'])

# %%
# Dropping unnecessary columns

# %%
content.drop(['Unnamed: 0'], axis=1, inplace=True)
content.drop(['User ID'], axis=1, inplace=True)
content.drop(['URL'], axis=1, inplace=True)
reactions.drop(['Unnamed: 0'], axis=1, inplace=True)
reactions.drop(['User ID'], axis=1, inplace=True)
reaction_type.drop(['Unnamed: 0'], axis=1, inplace=True)
# Out:
# C:\Users\rjsek\AppData\Local\Temp\ipykernel_34644\1382256780.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   content.drop(['Unnamed: 0'], axis=1, inplace=True)
# C:\Users\rjsek\AppData\Local\Temp\ipykernel_34644\1382256780.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   content.drop(['User ID'], axis=1, inplace=True)
# C:\Users\rjsek\AppData\Local\Temp\ipykernel_34644\1382256780.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
content
# Out:
#                                Content ID   Type        Category
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2  photo        Studying
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810  photo  healthy eating
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f  photo  healthy eating
# 3    356fff80-da4d-4785-9f43-bc1261031dc6  photo      technology
# 4    01ab84dd-6364-4236-abbb-3f237db77180  video            food
# ..                                    ...    ...             ...
# 994  c54b49c4-b1f2-4641-8595-1cbd19937845  photo         science
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c    GIF      technology
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b  audio        veganism
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    GIF         culture
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56  audio      technology
#
# [801 rows x 3 columns]

# %%
# Converting data types

# %%
import datetime

# %%
# Convert 'date_column' to datetime in the content DataFrame
reactions['Datetime'] = pd.to_datetime(reactions['Datetime'], errors='coerce')

# %%
# Renaming columns

# %%
# # Rename type column
# reaction_type.rename(columns={'Type':'Reaction_Type'},inplace=True)

# %%
# # Rename type column
# reactions.rename(columns={'Type':'Content_Type'},inplace=True)

# %%
reactions
# Out:
#                                  Content ID        Type            Datetime
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust 2020-11-07 09:43:50
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike 2021-06-17 12:22:51
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2      scared 2021-04-18 05:13:58
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust 2021-01-06 19:13:01
# 5      97522e57-d9ab-4bd6-97bf-c24d952602d2  interested 2020-08-23 12:25:58
# ...                                     ...         ...                 ...
# 25547  75d6b589-7fae-4a6d-b0d0-752845150e56     worried 2020-10-31 04:50:14
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56     dislike 2020-06-27 09:46:48
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56   intrigued 2021-02-16 17:17:02
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56     worried 2020-11-04 20:08:31
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56     cherish 2021-01-04 04:55:11
#
# [22534 rows x 3 columns]

# %%
reaction_type
# Out:
#            Type Sentiment  Score
# 0         heart  positive     60
# 1          want  positive     70
# 2       disgust  negative      0
# 3          hate  negative      5
# 4    interested  positive     30
# 5   indifferent   neutral     20
# 6          love  positive     65
# 7    super love  positive     75
# 8       cherish  positive     70
# 9         adore  positive     72
# 10         like  positive     50
# 11      dislike  negative     10
# 12    intrigued  positive     45
# 13      peeking   neutral     35
# 14       scared  negative     15
# 15      worried  negative     12

# %%
# Combining the datasets

# %%
# Step 1: Merge content and reactions on 'Content ID'
merged_df = pd.merge(reaction_type, reactions, on='Type', how='inner')

# %%
merged_df
# Out:
#           Type Sentiment  Score                            Content ID  \
# 0        heart  positive     60  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1        heart  positive     60  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2        heart  positive     60  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3        heart  positive     60  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 4        heart  positive     60  230c4e4d-70c3-461d-b42c-ec09396efb3f
# ...        ...       ...    ...                                   ...
# 22529  worried  negative     12  c54b49c4-b1f2-4641-8595-1cbd19937845
# 22530  worried  negative     12  c54b49c4-b1f2-4641-8595-1cbd19937845
# 22531  worried  negative     12  435007a5-6261-4d8b-b0a4-55fdc189754b
# 22532  worried  negative     12  75d6b589-7fae-4a6d-b0d0-752845150e56
# 22533  worried  negative     12  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                  Datetime
# 0     2021-04-11 14:29:59
# 1     2021-06-16 03:02:28
# 2     2020-12-25 00:09:41
# ...

# %%
# Step 2: Merge content and merged_df on 'Content ID'
df = pd.merge(merged_df, content, on='Content ID', how='inner')

# %%
df
# Out:
#         Type_x Sentiment  Score                            Content ID  \
# 0        heart  positive     60  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1         want  positive     70  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      disgust  negative      0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      disgust  negative      0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      disgust  negative      0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...        ...       ...    ...                                   ...
# 18379  peeking   neutral     35  a52f38d8-1c2e-4adc-b451-01c49f650195
# 18380  peeking   neutral     35  b7a5e38b-b990-4b8e-aaac-6cc9ee77f3d9
# 18381  peeking   neutral     35  1413f582-4261-4037-93bd-7356b0e9e017
# 18382   scared  negative     15  01ab84dd-6364-4236-abbb-3f237db77180
# 18383   scared  negative     15  aeff2a7a-2cc8-407a-8557-fa4e96b2425a
#
#                  Datetime Type_y        Category
# 0     2021-04-11 14:29:59  photo        Studying
# ...

# %%
# Renaming columns

# %%
# Rename type column
df.rename(columns={'Type_x':'Reaction_Type'},inplace=True)
df.rename(columns={'Type_y':'Content_Type'},inplace=True)

# %%
df
# Out:
#       Reaction_Type Sentiment  Score                            Content ID  \
# 0             heart  positive     60  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1              want  positive     70  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           disgust  negative      0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           disgust  negative      0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           disgust  negative      0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...             ...       ...    ...                                   ...
# 18379       peeking   neutral     35  a52f38d8-1c2e-4adc-b451-01c49f650195
# 18380       peeking   neutral     35  b7a5e38b-b990-4b8e-aaac-6cc9ee77f3d9
# 18381       peeking   neutral     35  1413f582-4261-4037-93bd-7356b0e9e017
# 18382        scared  negative     15  01ab84dd-6364-4236-abbb-3f237db77180
# 18383        scared  negative     15  aeff2a7a-2cc8-407a-8557-fa4e96b2425a
#
#                  Datetime Content_Type        Category
# ...

# %%
# Saving final df for advanced visuals

# %%
# Save Diminos as a CSV file
df.to_csv('SocialBuzz.csv', index=False)


from IPython.display import FileLink

# Create a download link for the CSV file
FileLink('SocialBuzz.csv')
# Out:
# C:\Users\rjsek\OneDrive\Documents\Work and Professional documents\Innomatics Research Labs\Forage\Accenture Data Visualization Internship\Data\SocialBuzz.csv

# %%
df
# Out:
#       Reaction_Type Sentiment  Score                            Content ID  \
# 0             heart  positive     60  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1              want  positive     70  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           disgust  negative      0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           disgust  negative      0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           disgust  negative      0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...             ...       ...    ...                                   ...
# 18379       peeking   neutral     35  a52f38d8-1c2e-4adc-b451-01c49f650195
# 18380       peeking   neutral     35  b7a5e38b-b990-4b8e-aaac-6cc9ee77f3d9
# 18381       peeking   neutral     35  1413f582-4261-4037-93bd-7356b0e9e017
# 18382        scared  negative     15  01ab84dd-6364-4236-abbb-3f237db77180
# 18383        scared  negative     15  aeff2a7a-2cc8-407a-8557-fa4e96b2425a
#
#                  Datetime Content_Type        Category
# ...

# %%
# Top 5 Performers

# %%
#group by category and calculate total score
top_five = df.groupby('Category').sum().sort_values(by='Score',ascending=False)
top_five.head(5)
# Out:
# C:\Users\rjsek\AppData\Local\Temp\ipykernel_34644\410151736.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   top_five = df.groupby('Category').sum().sort_values(by='Score',ascending=False)
#                 Score
# Category
# travel          53935
# science         53657
# healthy eating  52745
# animals         52443
# cooking         49681

# %%
# Saving the df for client submission

# %%
# top_five.to_csv('client_data.csv')

# %%
# Data Visualization

# %%
# Basic

# %%
# libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Categorical Data

# %%
# Bar Plots

# %%
# Bar plot for categorical data (e.g., 'Reaction_Type')
sns.countplot(x='Reaction_Type', data=df)
plt.title('Number of Posts per Reaction Type')

# Rotate x-axis labels and adjust alignment
plt.xticks(rotation=45, ha='right')

# Adjust layout to make sure everything fits
plt.tight_layout()

plt.show()

# %%
# Bar plot for categorical data (e.g., 'Sentiment')
sns.countplot(x='Sentiment', data=df)
plt.title('Number of Posts per Sentiment')

# Rotate x-axis labels and adjust alignment
#plt.xticks(rotation=45, ha='right')

# Adjust layout to make sure everything fits
plt.tight_layout()

plt.show()

# %%
# Bar plot for categorical data (e.g., 'Content_Type')
sns.countplot(x='Content_Type', data=df)
plt.title('Number of Posts per Content_Type')

# Rotate x-axis labels and adjust alignment
#plt.xticks(rotation=45, ha='right')

# Adjust layout to make sure everything fits
plt.tight_layout()

plt.show()

# %%
# Bar plot for categorical data (e.g., 'category')
sns.countplot(x='Category', data=df)
plt.title('Number of Posts per Category')

# Rotate x-axis labels and adjust alignment
plt.xticks(rotation=45, ha='right')

# Adjust layout to make sure everything fits
plt.tight_layout()

plt.show()

# %%
# Numerical Data

# %%
# Histogram

# %%
sns.histplot(df['Score'], kde=True)
plt.title('Distribution of Score')
plt.show()

# %%
# Time Series

# %%
df.set_index('Datetime').resample('D')['Score'].sum().plot()
plt.title('Reactions Over Time')
plt.show()

# %%
# Top 5

# %%
# Category

# %%
#

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# %%
sns.set(style="ticks", context="talk")

# %%
# 1. Top 5 Categories by Average Score
top_5_categories_by_score = df.groupby('Category')['Score'].sum().sort_values(ascending=False).head(5).reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='Score', y='Category', data=top_5_categories_by_score, palette='viridis')
plt.title('Top 5 Categories by Average Score', fontsize=16)
plt.xlabel('Average Score', fontsize=14)
plt.ylabel('Category', fontsize=14)
plt.tight_layout()
plt.show()

# %%
# 2. Average Score by Content Type
content_type_by_score = df.groupby('Content_Type')['Score'].sum().sort_values(ascending=False).reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='Score', y='Content_Type', data=content_type_by_score, palette='magma')
plt.title('Average Score by Content Type', fontsize=16)
plt.xlabel('Average Score', fontsize=14)
plt.ylabel('Content Type', fontsize=14)
plt.tight_layout()
plt.show()

# %%
# 3. Number of Posts Per Month
# Convert 'Datetime' to 'Month' period
df['Month'] = df['Datetime'].dt.to_period('M')

# Group by 'Month' and count 'Content ID'
posts_per_month = df.groupby('Month')['Content ID'].count().reset_index()

# Convert 'Month' to string for plotting
posts_per_month['Month'] = posts_per_month['Month'].astype(str)

# Plotting the data
plt.figure(figsize=(12, 6))
sns.lineplot(x='Month', y='Content ID', data=posts_per_month, marker='o', color='blue')
plt.title('Number of Posts Per Month', fontsize=16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 4. Top 5 Categories by Sentiment and Content Type
top_5_categories_by_sentiment_content = df.groupby(['Category', 'Sentiment', 'Content_Type']).size().reset_index(name='Count')
top_5_categories_by_sentiment_content = top_5_categories_by_sentiment_content.sort_values(by='Count', ascending=False).head(5)

plt.figure(figsize=(12, 8))
sns.catplot(x='Count', y='Category', hue='Sentiment', col='Content_Type', data=top_5_categories_by_sentiment_content, kind='bar', height=5, aspect=1)
plt.suptitle('Top 5 Categories by Sentiment and Content Type', fontsize=16)
plt.tight_layout()
plt.show()
